# %%
# %matplotlib notebook
from sklearn import datasets, model_selection
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.legend_handler import HandlerLine2D
from utils import *

# %%
################Choose dataset #################
X,y = spiral(200)
# X,y = datasets.make_moons(n_samples=1000,noise=0.01)
# X = np.concatenate([np.random.multivariate_normal([-1.5,0],np.eye(2)/10,1000),np.random.multivariate_normal([+1.5,0],np.eye(2)/10,1000)])
# y = np.concatenate([np.ones(1000),np.zeros(1000)])
nb_labels = 5
################################################
ids = np.random.permutation(y.shape[0])
X=X[ids]
y=y[ids]
txs=[]
tys=[]
for j in range(int(np.max(y))+1):
    txs.append(X[y==j][:nb_labels])
    tys.append(y[y==j][:nb_labels])
X_lab = np.concatenate(txs,axis=0)
y_lab = np.concatenate(tys,axis=0)
f,ax = plt.subplots()
f.set_size_inches(4,4)

scatter_dataset(ax,X,np.zeros_like(y),s=1,c='b')
scatter_dataset(ax,X_lab,y_lab,s=50,marker='x',c='r')
ax.set_title('dataset')
# return X,y, X_lab, Y_lab
ex = gen_examples(10000,X)
scatter_dataset(ax,ex,np.zeros(ex.shape[0]),s=1)
# Out:
# <img src="data:image/png;base64,..." width="399.76665435555947">

# %%
def plot_gan(f,ax):
    scale = 1.5
    xmin = -scale
    xmax = scale
    ymin = -scale
    ymax = scale
    xx, yy = make_meshgrid(xmin,xmax,ymin,ymax, h=0.05)
    ax[0].clear()
#     X_gen = ssgan.generate_random_samples(100)
    plot_contours(ax[0], ssgan.predict_fake, xx,yy,cmap=plt.cm.coolwarm, alpha=0.6)
    
    scatter_dataset(ax[0],X,np.zeros_like(y),s=0.5,c=(0.1,0.1,0.1))
    scatter_dataset(ax[0],X_lab,y_lab,s=5,marker='x')
    ax[0].set_title('classification')
    ax[0].set_xlim(xmin,xmax)
    ax[0].set_ylim(ymin,ymax)
    
    ax[1].clear()
#     X_gen=gen_examples(100, X)
    X_gen = ssgan.generate_random_samples(100, np.random.randint(0,4,200))
#     X_gen = gen_examples(100)
    plot_contours(ax[1], ssgan.discriminate, xx,yy,cmap=plt.cm.coolwarm, alpha=0.6)
    scatter_dataset(ax[1],X,np.zeros_like(y),s=1,c='b')
    ax[1].scatter(X_gen[:,0],X_gen[:,1],c='r',s=1)
    ax[1].set_title('real/fake discrimination')
    ax[1].set_xlim(xmin,xmax)
    ax[1].set_ylim(ymin,ymax)
    
    ax[2].clear()
    pred,acc = ssgan.predict(X,y,acc=True)
    scatter_dataset(ax[2],X,pred,s=1)
    ax[2].set_title('classification acc : %0.2f'%(acc))
    ax[2].set_xlim(xmin,xmax)
    ax[2].set_ylim(ymin,ymax)
    
    f.canvas.draw()

# %%
class Model ():
    
    def __init__(self, sess, batch_size = 100, x_dim=2, nb_class = 2, lr_d = 0.01, lr_g = 0.01,
                 z_dim = 2, print_frequency=199, nb_epoch = 100,verbose=True):
        self.sess = sess
        self.z_dim = z_dim
        self.x_dim = x_dim
        self.nb_class = nb_class
        self.nb_epoch = nb_epoch
        self.batch_size = batch_size
        self.verbose = verbose
        self.print_frequency = print_frequency
        self.lr_d = lr_d
        self.lr_g = lr_g
        
        self.build_model()

    def generator(self, z, label, reuse=False):
        with tf.variable_scope("generator") as scope:
            if reuse:
                scope.reuse_variables()
            
            code = tf.one_hot(label,depth=self.nb_class)
            seed = tf.concat([z, code],axis=1)
                
            regularizer = tf.contrib.layers.l2_regularizer(scale=0.9)    

            h = tf.layers.dense(seed,20, activation=tf.nn.relu,kernel_regularizer=regularizer)
            h = tf.layers.dense(z,5, activation=tf.nn.relu,kernel_regularizer=regularizer)
            h = tf.layers.dense(h,self.x_dim)
            return h

    def discriminator(self, inp, reuse=False):
        with tf.variable_scope("discriminator") as scope:
            if reuse:
                scope.reuse_variables()
            regularizer = tf.contrib.layers.l2_regularizer(scale=0.2)    
            h = tf.layers.dense(inp,20, activation=tf.nn.relu,kernel_regularizer=regularizer)
            layer = h

            h = tf.layers.dense(h,5, activation=tf.nn.relu, kernel_regularizer=regularizer)
            class_logits = tf.layers.dense(h,self.nb_class)
            dis = tf.layers.dense(h,1)
            
            return class_logits, layer, dis

    def build_model(self):
        self.lab = tf.placeholder(tf.float32,[None,self.x_dim], name='input_lbl_data')
        self.unl = tf.placeholder(tf.float32,[None,self.x_dim], name='input_unl_data')
        self.z = tf.placeholder(tf.float32, [None,self.z_dim],name='z_seed')
        self.lbl = tf.placeholder(tf.int64, [None],name='labels')
        self.fake_lbl = tf.placeholder(tf.int64, [None],name='labels')
        
        self.gen = self.generator(self.z,self.fake_lbl,reuse=False)
        self.l_lab, _, self.dis_lab = self.discriminator(self.lab, reuse=False)
        self.l_unl, self.layer_r,self.dis_unl = self.discriminator(self.unl, reuse=True)
        self.l_fake, self.layer_f,self.dis_fake = self.discriminator(self.gen, reuse=True)
        
        xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits
        sigmoid = tf.nn.sigmoid_cross_entropy_with_logits
        self.d_loss = tf.reduce_mean(sigmoid(logits=self.dis_unl,labels=tf.ones_like(self.dis_unl)))+\
                        tf.reduce_mean(sigmoid(logits=self.dis_fake,labels=tf.zeros_like(self.dis_fake)))
        self.c_loss = tf.reduce_mean(xentropy(logits=self.l_lab,labels=self.lbl)) + \
                        tf.reduce_mean(xentropy(logits=self.l_fake,labels=self.fake_lbl))    
        #loss generator
        self.fm_loss = tf.reduce_mean(tf.reduce_mean(tf.square(self.layer_r-self.layer_f),axis=0))
        self.g_loss = tf.reduce_mean(sigmoid(logits=self.dis_fake,labels=tf.ones_like(self.dis_fake)))
        
        self.prediction_fake = tf.cast(tf.argmax(self.l_lab,1),tf.int32)
        self.prediction = tf.cast(tf.argmax(self.l_lab,1),tf.int32)                                 

        self.correct_prediction = tf.equal(tf.argmax(self.l_lab, 1), self.lbl)
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
        self.dis = 1-tf.cast(tf.greater(self.dis_lab[:,-1],0.5),tf.float32)
    
        t_vars = tf.trainable_variables()
        self.d_vars = [var for var in t_vars if 'discriminator' in var.name]
        self.g_vars = [var for var in t_vars if 'generator' in var.name]    
        self.d_optim = tf.train.AdamOptimizer(self.lr_d).minimize(loss=self.d_loss, var_list=self.d_vars)
        self.g_optim = tf.train.AdamOptimizer(self.lr_g).minimize(loss=self.g_loss, var_list=self.g_vars)
        self.c_optim = tf.train.AdamOptimizer(self.lr_d).minimize(
            loss=self.c_loss, var_list=self.d_vars+self.g_vars)

        

    def train(self,f,ax, X_unl,X_lab, y, X_test,y_test):
        self.trainx_unl = X_unl
        self.trainx_unl2 = X_unl.copy()
        self.trainy = y
        self.trainx = X_lab
        self.testx = X_test
        self.testy = y_test
        
        self.nb_examples_unl = self.trainx_unl.shape[0]
        self.nb_examples_lab = self.trainx.shape[0]
        self.nb_step = self.nb_examples_unl//self.batch_size
        
        tx = []
        ty = []
        for t in range(self.nb_examples_unl//self.nb_examples_lab):
            inds = np.random.permutation(self.nb_examples_lab)
            tx.append(self.trainx[inds])
            ty.append(self.trainy[inds])
        self.trainx = np.concatenate(tx, axis=0)
        self.trainy = np.concatenate(ty, axis=0)

        self.sess.run(tf.global_variables_initializer())
        for epoch in range(self.nb_epoch):
            ll_d = 0

            for step in range(self.nb_step): 
                ids = np.random.permutation(self.trainx.shape[0])
                self.trainx = self.trainx[ids]
                self.trainy = self.trainy[ids]
                self.trainx_unl = self.trainx_unl[np.random.permutation(self.trainx_unl.shape[0])]
                self.trainx_unl2 = self.trainx_unl2[np.random.permutation(self.trainx_unl2.shape[0])]

                ll_d = 0
                ll_g = 0 
                ll_c = 0
                for step in range(self.nb_step):
                    ran_from = step * self.batch_size
                    ran_to = (step+1) * self.batch_size
                    
                    feed_dict={self.unl:self.trainx_unl[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.d_optim, self.d_loss],feed_dict=feed_dict)
                    ll_d += ll
                    
                    feed_dict={self.lab:self.trainx[ran_from:ran_to],
                               self.lbl:self.trainy[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.c_optim, self.c_loss],feed_dict=feed_dict)
                    ll_c += ll
                    
                    feed_dict={self.unl:self.trainx_unl2[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.g_optim, self.fm_loss],feed_dict=feed_dict)
                    ll_g += ll
                    
                ll_d /= self.nb_step
                ll_g /= self.nb_step 
                ll_c /= self.nb_step
                                           
            if (epoch % self.print_frequency == 0):
                train_acc = self.sess.run(self.accuracy,feed_dict={self.lab:X_lab,
                                                                   self.lbl:y})
                test_acc = self.sess.run(self.accuracy,feed_dict={self.lab:X_test, 
                                                                  self.lbl:y_test})

                print('epoch %d | loss d = %0.4f | loss g = %0.4f | loss c = %0.4f | train acc = %0.2f | test acc = %0.2f '
                      %(epoch, ll_d, ll_g,ll_c, train_acc*100, test_acc*100))
                plot_gan(f,ax)

    def predict(self, X_test, y_test=False,acc=False):
        if acc == False:  
            return self.sess.run(self.prediction ,feed_dict={self.lab:X_test})

        return self.sess.run([self.prediction, self.accuracy],feed_dict={self.lab:X_test,
                                                                         self.lbl:y_test})
        
    
    def predict_fake(self, X_test, y_test=False,acc=False):
        if acc == False:    
            return self.sess.run(self.prediction_fake ,feed_dict={self.lab:X_test})
        
        return self.sess.run([self.prediction, self.accuracy],feed_dict={self.lab:X_test,
                                                                         self.lbl:y_test})
                                         
    
    def discriminate(self, X_test, y_test=None):
        if y_test == None:     
            pred = self.sess.run(self.dis ,feed_dict={self.lab:X_test})
            return pred
                                 

    def generate_random_samples(self, nb_samples, label):
        return self.sess.run(self.gen,feed_dict={self.z:np.random.randn(nb_samples,self.z_dim),
                                                self.fake_lbl: label})

# %%
tf.reset_default_graph()
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
ssgan = Model(sess, nb_epoch=1000, lr_g=0.0003, lr_d=0.0003, print_frequency=1,nb_class=4,batch_size=100)

f, ax = plt.subplots(1,3, sharex=True)
f.set_size_inches(10,3)
f.subplots_adjust(hspace=0.5)
plt.ion()
f.show()
f.canvas.draw()

ssgan.train(f,ax,X,X_lab,y_lab,X,y)
f.close()
# Out:
# <img src="data:image/png;base64,..." width="999.4166358888987">
# epoch 0 | loss d = 1.3614 | loss g = 0.0373 | loss c = 2.7172 | train acc = 45.00 | test acc = 38.50
# epoch 1 | loss d = 1.3730 | loss g = 0.0311 | loss c = 2.6856 | train acc = 55.00 | test acc = 43.25
# epoch 2 | loss d = 1.3942 | loss g = 0.0272 | loss c = 2.6413 | train acc = 55.00 | test acc = 51.25
# epoch 3 | loss d = 1.4089 | loss g = 0.0274 | loss c = 2.6254 | train acc = 65.00 | test acc = 53.62
# epoch 4 | loss d = 1.4186 | loss g = 0.0277 | loss c = 2.6007 | train acc = 70.00 | test acc = 56.00
# epoch 5 | loss d = 1.4246 | loss g = 0.0310 | loss c = 2.5736 | train acc = 70.00 | test acc = 57.88
# epoch 6 | loss d = 1.4317 | loss g = 0.0353 | loss c = 2.5480 | train acc = 70.00 | test acc = 57.00
# epoch 7 | loss d = 1.4372 | loss g = 0.0398 | loss c = 2.5185 | train acc = 70.00 | test acc = 54.75
# epoch 8 | loss d = 1.4323 | loss g = 0.0472 | loss c = 2.4852 | train acc = 50.00 | test acc = 45.38
# epoch 9 | loss d = 1.4255 | loss g = 0.0535 | loss c = 2.4693 | train acc = 50.00 | test acc = 44.62
# epoch 10 | loss d = 1.4227 | loss g = 0.0572 | loss c = 2.4467 | train acc = 50.00 | test acc = 44.87
# epoch 11 | loss d = 1.4205 | loss g = 0.0667 | loss c = 2.4075 | train acc = 50.00 | test acc = 46.63
# epoch 12 | loss d = 1.4167 | loss g = 0.0684 | loss c = 2.3820 | train acc = 55.00 | test acc = 48.63
# epoch 13 | loss d = 1.4077 | loss g = 0.0753 | loss c = 2.3550 | train acc = 60.00 | test acc = 50.25
# epoch 14 | loss d = 1.3948 | loss g = 0.0735 | loss c = 2.3276 | train acc = 65.00 | test acc = 52.50
# epoch 15 | loss d = 1.3791 | loss g = 0.0792 | loss c = 2.3079 | train acc = 65.00 | test acc = 55.62
# epoch 16 | loss d = 1.3620 | loss g = 0.0799 | loss c = 2.2897 | train acc = 70.00 | test acc = 59.62
# epoch 17 | loss d = 1.3461 | loss g = 0.0825 | loss c = 2.2609 | train acc = 75.00 | test acc = 64.13
# epoch 18 | loss d = 1.3366 | loss g = 0.0795 | loss c = 2.2479 | train acc = 75.00 | test acc = 66.50
# epoch 19 | loss d = 1.3245 | loss g = 0.0830 | loss c = 2.2124 | train acc = 80.00 | test acc = 67.12
# epoch 20 | loss d = 1.3102 | loss g = 0.0871 | loss c = 2.1970 | train acc = 80.00 | test acc = 67.62
# epoch 21 | loss d = 1.3034 | loss g = 0.0883 | loss c = 2.1727 | train acc = 80.00 | test acc = 68.62
# epoch 22 | loss d = 1.2942 | loss g = 0.0937 | loss c = 2.1549 | train acc = 80.00 | test acc = 68.88
# epoch 23 | loss d = 1.2886 | loss g = 0.0963 | loss c = 2.1492 | train acc = 80.00 | test acc = 69.00
# epoch 24 | loss d = 1.2778 | loss g = 0.1121 | loss c = 2.1455 | train acc = 80.00 | test acc = 69.12
# epoch 25 | loss d = 1.2711 | loss g = 0.1135 | loss c = 2.1340 | train acc = 85.00 | test acc = 69.87
# epoch 26 | loss d = 1.2664 | loss g = 0.1221 | loss c = 2.1301 | train acc = 85.00 | test acc = 70.62
# epoch 27 | loss d = 1.2740 | loss g = 0.1199 | loss c = 2.1394 | train acc = 85.00 | test acc = 71.62
# epoch 28 | loss d = 1.2712 | loss g = 0.1341 | loss c = 2.0945 | train acc = 90.00 | test acc = 72.87
# epoch 29 | loss d = 1.2755 | loss g = 0.1350 | loss c = 2.1203 | train acc = 90.00 | test acc = 73.62
# epoch 30 | loss d = 1.2724 | loss g = 0.1423 | loss c = 2.1027 | train acc = 95.00 | test acc = 74.37
# epoch 31 | loss d = 1.2729 | loss g = 0.1469 | loss c = 2.1081 | train acc = 95.00 | test acc = 75.75
# epoch 32 | loss d = 1.2721 | loss g = 0.1465 | loss c = 2.0709 | train acc = 100.00 | test acc = 77.25
# epoch 33 | loss d = 1.2512 | loss g = 0.1536 | loss c = 2.1124 | train acc = 100.00 | test acc = 78.00
# epoch 34 | loss d = 1.2206 | loss g = 0.1620 | loss c = 2.0577 | train acc = 95.00 | test acc = 76.25
# epoch 35 | loss d = 1.1915 | loss g = 0.1545 | loss c = 2.0961 | train acc = 95.00 | test acc = 74.25
# epoch 36 | loss d = 1.1439 | loss g = 0.1650 | loss c = 2.1150 | train acc = 95.00 | test acc = 73.87
# epoch 37 | loss d = 1.1362 | loss g = 0.1821 | loss c = 2.0665 | train acc = 90.00 | test acc = 74.25
# epoch 38 | loss d = 1.1098 | loss g = 0.1974 | loss c = 2.0174 | train acc = 95.00 | test acc = 74.87
# epoch 39 | loss d = 1.0638 | loss g = 0.1897 | loss c = 2.0734 | train acc = 95.00 | test acc = 74.37
# epoch 40 | loss d = 1.0385 | loss g = 0.1858 | loss c = 2.0654 | train acc = 95.00 | test acc = 74.87
# epoch 41 | loss d = 1.0424 | loss g = 0.1993 | loss c = 2.0520 | train acc = 95.00 | test acc = 73.00
# epoch 42 | loss d = 1.0477 | loss g = 0.2064 | loss c = 2.1268 | train acc = 90.00 | test acc = 70.62
# epoch 43 | loss d = 1.0655 | loss g = 0.2025 | loss c = 2.1091 | train acc = 90.00 | test acc = 70.75
# epoch 44 | loss d = 1.0945 | loss g = 0.1983 | loss c = 2.1936 | train acc = 90.00 | test acc = 71.25
# epoch 45 | loss d = 1.1277 | loss g = 0.1834 | loss c = 2.1912 | train acc = 95.00 | test acc = 71.37
# epoch 46 | loss d = 1.1426 | loss g = 0.1801 | loss c = 2.1924 | train acc = 95.00 | test acc = 71.88
# epoch 47 | loss d = 1.2186 | loss g = 0.1757 | loss c = 2.2356 | train acc = 95.00 | test acc = 71.87
# epoch 48 | loss d = 1.1881 | loss g = 0.1509 | loss c = 2.2179 | train acc = 95.00 | test acc = 73.00
# epoch 49 | loss d = 1.2744 | loss g = 0.1448 | loss c = 2.1597 | train acc = 95.00 | test acc = 74.25
# epoch 50 | loss d = 1.2889 | loss g = 0.1401 | loss c = 2.1982 | train acc = 95.00 | test acc = 75.87
# epoch 51 | loss d = 1.2901 | loss g = 0.1392 | loss c = 2.1958 | train acc = 95.00 | test acc = 74.63
# epoch 52 | loss d = 1.2302 | loss g = 0.1393 | loss c = 2.1569 | train acc = 95.00 | test acc = 75.25
# epoch 53 | loss d = 1.2369 | loss g = 0.1368 | loss c = 2.1520 | train acc = 90.00 | test acc = 75.50
# epoch 54 | loss d = 1.1967 | loss g = 0.1457 | loss c = 2.1556 | train acc = 90.00 | test acc = 75.88
# epoch 55 | loss d = 1.1816 | loss g = 0.1565 | loss c = 2.1603 | train acc = 95.00 | test acc = 74.37
# epoch 56 | loss d = 1.1745 | loss g = 0.1832 | loss c = 2.2235 | train acc = 90.00 | test acc = 71.88
# epoch 57 | loss d = 1.1505 | loss g = 0.1922 | loss c = 2.2033 | train acc = 90.00 | test acc = 68.62
# epoch 58 | loss d = 1.1333 | loss g = 0.2135 | loss c = 2.2540 | train acc = 90.00 | test acc = 66.12
# epoch 59 | loss d = 1.1137 | loss g = 0.2010 | loss c = 2.2321 | train acc = 85.00 | test acc = 65.50
# epoch 60 | loss d = 1.1052 | loss g = 0.2106 | loss c = 2.3047 | train acc = 85.00 | test acc = 65.12
# epoch 61 | loss d = 1.0974 | loss g = 0.2104 | loss c = 2.2601 | train acc = 85.00 | test acc = 65.25
# epoch 62 | loss d = 1.0744 | loss g = 0.1969 | loss c = 2.2231 | train acc = 85.00 | test acc = 67.00
# epoch 63 | loss d = 1.0829 | loss g = 0.1784 | loss c = 2.2318 | train acc = 85.00 | test acc = 68.13
# epoch 64 | loss d = 1.0913 | loss g = 0.1716 | loss c = 2.1980 | train acc = 85.00 | test acc = 68.87
# epoch 65 | loss d = 1.1016 | loss g = 0.1735 | loss c = 2.1965 | train acc = 90.00 | test acc = 70.50
# epoch 66 | loss d = 1.1151 | loss g = 0.1623 | loss c = 2.1750 | train acc = 90.00 | test acc = 71.50
# epoch 67 | loss d = 1.1108 | loss g = 0.1563 | loss c = 2.1757 | train acc = 90.00 | test acc = 71.87
# epoch 68 | loss d = 1.1393 | loss g = 0.1575 | loss c = 2.1528 | train acc = 90.00 | test acc = 71.38
# epoch 69 | loss d = 1.1638 | loss g = 0.1411 | loss c = 2.1219 | train acc = 90.00 | test acc = 71.75
# epoch 70 | loss d = 1.1730 | loss g = 0.1413 | loss c = 2.1750 | train acc = 90.00 | test acc = 71.50
# epoch 71 | loss d = 1.1784 | loss g = 0.1444 | loss c = 2.1337 | train acc = 90.00 | test acc = 71.38
# epoch 72 | loss d = 1.1909 | loss g = 0.1516 | loss c = 2.1613 | train acc = 90.00 | test acc = 71.37
# epoch 73 | loss d = 1.2072 | loss g = 0.1368 | loss c = 2.0843 | train acc = 90.00 | test acc = 71.50
# epoch 74 | loss d = 1.2297 | loss g = 0.1427 | loss c = 2.0936 | train acc = 90.00 | test acc = 70.87
# epoch 75 | loss d = 1.2354 | loss g = 0.1519 | loss c = 2.1192 | train acc = 90.00 | test acc = 70.50
# epoch 76 | loss d = 1.2504 | loss g = 0.1540 | loss c = 2.1047 | train acc = 90.00 | test acc = 70.00
# epoch 77 | loss d = 1.2663 | loss g = 0.1653 | loss c = 2.0873 | train acc = 90.00 | test acc = 70.00
# epoch 78 | loss d = 1.2587 | loss g = 0.1644 | loss c = 2.0681 | train acc = 90.00 | test acc = 69.87
# epoch 79 | loss d = 1.2469 | loss g = 0.1549 | loss c = 2.0940 | train acc = 90.00 | test acc = 69.62
# epoch 80 | loss d = 1.2291 | loss g = 0.1672 | loss c = 2.1079 | train acc = 90.00 | test acc = 70.00
# epoch 81 | loss d = 1.2240 | loss g = 0.1651 | loss c = 2.0835 | train acc = 90.00 | test acc = 69.50
# epoch 82 | loss d = 1.1952 | loss g = 0.1789 | loss c = 2.0934 | train acc = 90.00 | test acc = 69.25
# epoch 83 | loss d = 1.2129 | loss g = 0.1693 | loss c = 2.0975 | train acc = 90.00 | test acc = 69.38
# epoch 84 | loss d = 1.1688 | loss g = 0.1871 | loss c = 2.1091 | train acc = 90.00 | test acc = 69.00
# epoch 85 | loss d = 1.1426 | loss g = 0.1774 | loss c = 2.1403 | train acc = 90.00 | test acc = 68.75
# epoch 86 | loss d = 1.1399 | loss g = 0.1806 | loss c = 2.1392 | train acc = 90.00 | test acc = 68.37
# epoch 87 | loss d = 1.1266 | loss g = 0.1751 | loss c = 2.0758 | train acc = 90.00 | test acc = 68.25
# epoch 88 | loss d = 1.1242 | loss g = 0.1950 | loss c = 2.1404 | train acc = 85.00 | test acc = 69.37
# epoch 89 | loss d = 1.1188 | loss g = 0.1941 | loss c = 2.1286 | train acc = 80.00 | test acc = 68.25
# epoch 90 | loss d = 1.1519 | loss g = 0.1940 | loss c = 2.1887 | train acc = 85.00 | test acc = 68.62
# epoch 91 | loss d = 1.1317 | loss g = 0.1993 | loss c = 2.1541 | train acc = 90.00 | test acc = 69.62
# epoch 92 | loss d = 1.1200 | loss g = 0.2073 | loss c = 2.1612 | train acc = 85.00 | test acc = 68.37
# epoch 93 | loss d = 1.1090 | loss g = 0.1964 | loss c = 2.1096 | train acc = 85.00 | test acc = 69.87
# epoch 94 | loss d = 1.0950 | loss g = 0.2012 | loss c = 2.1701 | train acc = 90.00 | test acc = 71.00
# epoch 95 | loss d = 1.1014 | loss g = 0.1984 | loss c = 2.1165 | train acc = 95.00 | test acc = 72.25
# epoch 96 | loss d = 1.0911 | loss g = 0.1999 | loss c = 2.1754 | train acc = 95.00 | test acc = 71.88
# epoch 97 | loss d = 1.0802 | loss g = 0.2088 | loss c = 2.1283 | train acc = 95.00 | test acc = 72.00
# epoch 98 | loss d = 1.0498 | loss g = 0.1999 | loss c = 2.1189 | train acc = 95.00 | test acc = 73.00
# epoch 99 | loss d = 1.0235 | loss g = 0.2022 | loss c = 2.1280 | train acc = 95.00 | test acc = 73.00
# epoch 100 | loss d = 1.0120 | loss g = 0.2133 | loss c = 2.1275 | train acc = 95.00 | test acc = 73.12
# epoch 101 | loss d = 1.0110 | loss g = 0.2012 | loss c = 2.1358 | train acc = 95.00 | test acc = 74.12
# epoch 102 | loss d = 1.0706 | loss g = 0.2079 | loss c = 2.0618 | train acc = 95.00 | test acc = 76.63
# epoch 103 | loss d = 1.0830 | loss g = 0.2113 | loss c = 2.1403 | train acc = 95.00 | test acc = 77.75
# epoch 104 | loss d = 1.0817 | loss g = 0.2020 | loss c = 2.1300 | train acc = 95.00 | test acc = 78.37
# epoch 105 | loss d = 1.1177 | loss g = 0.2108 | loss c = 2.1185 | train acc = 95.00 | test acc = 79.25
# epoch 106 | loss d = 1.1291 | loss g = 0.1930 | loss c = 2.0894 | train acc = 100.00 | test acc = 79.62
# epoch 107 | loss d = 1.1343 | loss g = 0.2045 | loss c = 2.0941 | train acc = 100.00 | test acc = 79.50
# epoch 108 | loss d = 1.1495 | loss g = 0.2048 | loss c = 2.0566 | train acc = 100.00 | test acc = 79.50
# epoch 109 | loss d = 1.1235 | loss g = 0.2073 | loss c = 2.0802 | train acc = 100.00 | test acc = 80.12
# epoch 110 | loss d = 1.1187 | loss g = 0.2032 | loss c = 2.0896 | train acc = 100.00 | test acc = 80.25
# epoch 111 | loss d = 1.1468 | loss g = 0.1856 | loss c = 2.0614 | train acc = 100.00 | test acc = 80.12
# epoch 112 | loss d = 1.1195 | loss g = 0.1815 | loss c = 2.0764 | train acc = 100.00 | test acc = 81.12
# epoch 113 | loss d = 1.1415 | loss g = 0.1859 | loss c = 2.0875 | train acc = 100.00 | test acc = 80.88
# epoch 114 | loss d = 1.1889 | loss g = 0.1788 | loss c = 2.0430 | train acc = 100.00 | test acc = 81.88
# epoch 115 | loss d = 1.1888 | loss g = 0.1755 | loss c = 2.1004 | train acc = 100.00 | test acc = 81.00
# epoch 116 | loss d = 1.1800 | loss g = 0.1756 | loss c = 2.1167 | train acc = 100.00 | test acc = 81.25
# epoch 117 | loss d = 1.2085 | loss g = 0.1759 | loss c = 2.1265 | train acc = 100.00 | test acc = 82.50
# epoch 118 | loss d = 1.1874 | loss g = 0.1681 | loss c = 2.0711 | train acc = 100.00 | test acc = 82.50
# epoch 119 | loss d = 1.1940 | loss g = 0.1722 | loss c = 2.0354 | train acc = 100.00 | test acc = 84.13
# epoch 120 | loss d = 1.1830 | loss g = 0.1627 | loss c = 2.0462 | train acc = 100.00 | test acc = 84.38
# epoch 121 | loss d = 1.1835 | loss g = 0.1652 | loss c = 2.0290 | train acc = 100.00 | test acc = 83.00
# epoch 122 | loss d = 1.1892 | loss g = 0.1690 | loss c = 2.0713 | train acc = 100.00 | test acc = 84.25
# epoch 123 | loss d = 1.1769 | loss g = 0.1643 | loss c = 2.0444 | train acc = 100.00 | test acc = 83.62
# epoch 124 | loss d = 1.2192 | loss g = 0.1616 | loss c = 2.0788 | train acc = 100.00 | test acc = 83.50
# epoch 125 | loss d = 1.1959 | loss g = 0.1719 | loss c = 2.0719 | train acc = 100.00 | test acc = 83.25
# epoch 126 | loss d = 1.1706 | loss g = 0.1657 | loss c = 2.0616 | train acc = 100.00 | test acc = 84.38
# epoch 127 | loss d = 1.1946 | loss g = 0.1583 | loss c = 2.0489 | train acc = 100.00 | test acc = 84.62
# epoch 128 | loss d = 1.1782 | loss g = 0.1681 | loss c = 2.0843 | train acc = 100.00 | test acc = 85.25
# epoch 129 | loss d = 1.1999 | loss g = 0.1714 | loss c = 2.0792 | train acc = 100.00 | test acc = 83.25
# epoch 130 | loss d = 1.2164 | loss g = 0.1611 | loss c = 2.1056 | train acc = 100.00 | test acc = 84.62
# epoch 131 | loss d = 1.1953 | loss g = 0.1638 | loss c = 2.1161 | train acc = 100.00 | test acc = 83.12
# epoch 132 | loss d = 1.2168 | loss g = 0.1617 | loss c = 2.1407 | train acc = 100.00 | test acc = 86.00
# epoch 133 | loss d = 1.2491 | loss g = 0.1695 | loss c = 2.1004 | train acc = 100.00 | test acc = 85.75
# epoch 134 | loss d = 1.2688 | loss g = 0.1623 | loss c = 2.1172 | train acc = 100.00 | test acc = 85.75
# epoch 135 | loss d = 1.2746 | loss g = 0.1611 | loss c = 2.1087 | train acc = 100.00 | test acc = 86.37
# epoch 136 | loss d = 1.2748 | loss g = 0.1602 | loss c = 2.0987 | train acc = 100.00 | test acc = 85.00
# epoch 137 | loss d = 1.2693 | loss g = 0.1611 | loss c = 2.0922 | train acc = 100.00 | test acc = 85.12
# epoch 138 | loss d = 1.2634 | loss g = 0.1555 | loss c = 2.1319 | train acc = 100.00 | test acc = 85.25
# epoch 139 | loss d = 1.2773 | loss g = 0.1475 | loss c = 2.1007 | train acc = 100.00 | test acc = 85.50
# epoch 140 | loss d = 1.2927 | loss g = 0.1542 | loss c = 2.0735 | train acc = 100.00 | test acc = 84.75
# epoch 141 | loss d = 1.3118 | loss g = 0.1485 | loss c = 2.0866 | train acc = 100.00 | test acc = 84.87
# epoch 142 | loss d = 1.2575 | loss g = 0.1494 | loss c = 2.0923 | train acc = 100.00 | test acc = 84.75
# epoch 143 | loss d = 1.2691 | loss g = 0.1467 | loss c = 2.1090 | train acc = 100.00 | test acc = 85.00
# epoch 144 | loss d = 1.2750 | loss g = 0.1483 | loss c = 2.1005 | train acc = 100.00 | test acc = 84.62
# epoch 145 | loss d = 1.2836 | loss g = 0.1455 | loss c = 2.0147 | train acc = 100.00 | test acc = 84.38
# epoch 146 | loss d = 1.2600 | loss g = 0.1432 | loss c = 2.0766 | train acc = 100.00 | test acc = 84.75
# epoch 147 | loss d = 1.2700 | loss g = 0.1441 | loss c = 2.0739 | train acc = 100.00 | test acc = 84.75
# epoch 148 | loss d = 1.2841 | loss g = 0.1448 | loss c = 2.0277 | train acc = 100.00 | test acc = 84.75
# epoch 149 | loss d = 1.2874 | loss g = 0.1514 | loss c = 2.0617 | train acc = 100.00 | test acc = 84.75
# epoch 150 | loss d = 1.2772 | loss g = 0.1474 | loss c = 2.0783 | train acc = 100.00 | test acc = 84.75
# epoch 151 | loss d = 1.2562 | loss g = 0.1493 | loss c = 2.0570 | train acc = 100.00 | test acc = 85.12
# epoch 152 | loss d = 1.2680 | loss g = 0.1489 | loss c = 2.0339 | train acc = 100.00 | test acc = 84.75
# epoch 153 | loss d = 1.2878 | loss g = 0.1512 | loss c = 2.0827 | train acc = 100.00 | test acc = 85.12
# epoch 154 | loss d = 1.2962 | loss g = 0.1485 | loss c = 2.0702 | train acc = 100.00 | test acc = 85.37
# epoch 155 | loss d = 1.2825 | loss g = 0.1463 | loss c = 2.0226 | train acc = 100.00 | test acc = 85.75
# epoch 156 | loss d = 1.2853 | loss g = 0.1488 | loss c = 2.0289 | train acc = 100.00 | test acc = 85.25
# epoch 157 | loss d = 1.2800 | loss g = 0.1459 | loss c = 2.0610 | train acc = 100.00 | test acc = 85.00
# epoch 158 | loss d = 1.2684 | loss g = 0.1476 | loss c = 2.0844 | train acc = 100.00 | test acc = 85.87
