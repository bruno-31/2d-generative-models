# %%
# %matplotlib notebook
from sklearn import datasets, model_selection
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.legend_handler import HandlerLine2D
from utils import *

# %%
################Choose dataset #################
X,y = spiral(200)
# X,y = datasets.make_moons(n_samples=1000,noise=0.01)
# X = np.concatenate([np.random.multivariate_normal([-1.5,0],np.eye(2)/10,1000),np.random.multivariate_normal([+1.5,0],np.eye(2)/10,1000)])
# y = np.concatenate([np.ones(1000),np.zeros(1000)])
nb_labels = 5
################################################
ids = np.random.permutation(y.shape[0])
X=X[ids]
y=y[ids]
txs=[]
tys=[]
for j in range(int(np.max(y))+1):
    txs.append(X[y==j][:nb_labels])
    tys.append(y[y==j][:nb_labels])
X_lab = np.concatenate(txs,axis=0)
y_lab = np.concatenate(tys,axis=0)
f,ax = plt.subplots()
f.set_size_inches(4,4)

scatter_dataset(ax,X,np.zeros_like(y),s=1,c='b')
scatter_dataset(ax,X_lab,y_lab,s=50,marker='x',c='r')
ax.set_title('dataset')
# return X,y, X_lab, Y_lab
ex = gen_examples(10000,X)
scatter_dataset(ax,ex,np.zeros(ex.shape[0]),s=1)

##########compute moments labeled###############
mom = []
for j in range(int(np.max(y))+1):
    mean = np.mean(X_lab[y_lab==j][:],axis=0)
    print(mean.shape)
    mom.append(mean)
mom=np.stack(mom)    
mom.shape

scatter_dataset(ax,mom, np.arange(4),s=10)
# Out:
# <img src="data:image/png;base64,..." width="399.76665435555947">
# (2,)
# (2,)
# (2,)
# (2,)

# %%
def plot_gan(f,ax):
    scale = 1.5
    xmin = -scale
    xmax = scale
    ymin = -scale
    ymax = scale
    xx, yy = make_meshgrid(xmin,xmax,ymin,ymax, h=0.05)
    ax[0].clear()
#     X_gen = ssgan.generate_random_samples(100)
    plot_contours(ax[0], ssgan.predict_fake, xx,yy,cmap=plt.cm.coolwarm, alpha=0.6)
    
    scatter_dataset(ax[0],X,np.zeros_like(y),s=0.5,c=(0.1,0.1,0.1))
    scatter_dataset(ax[0],X_lab,y_lab,s=5,marker='x')
    ax[0].set_title('classification')
    ax[0].set_xlim(xmin,xmax)
    ax[0].set_ylim(ymin,ymax)
    
    ax[1].clear()
#     X_gen=gen_examples(100, X)
    y_gen = np.concatenate([0*np.ones(50),np.ones(50),2*np.ones(50),3*np.ones(50)])
    X_gen = ssgan.generate_random_samples(200, y_gen)
#     X_gen = gen_examples(100)
    plot_contours(ax[1], ssgan.discriminate, xx,yy,cmap=plt.cm.coolwarm, alpha=0.6)
    scatter_dataset(ax[1],X,np.zeros_like(y),s=1,c='b')
#     ax[1].scatter(X_gen[:,0],X_gen[:,1],c='r',s=1)
    scatter_dataset(ax[1],X_gen,y_gen,s=1)
    ax[1].set_title('real/fake discrimination')
    ax[1].set_xlim(xmin,xmax)
    ax[1].set_ylim(ymin,ymax)
    
    ax[2].clear()
    pred,acc = ssgan.predict(X,y,acc=True)
    scatter_dataset(ax[2],X,pred,s=1)
    ax[2].set_title('classification acc : %0.2f'%(acc))
    ax[2].set_xlim(xmin,xmax)
    ax[2].set_ylim(ymin,ymax)
    
    f.canvas.draw()

# %%
class Model ():
    
    def __init__(self, sess, batch_size = 100, x_dim=2, nb_class = 2, lr_d = 0.01, lr_g = 0.01,
                 z_dim = 2, print_frequency=199, nb_epoch = 100,verbose=True):
        self.sess = sess
        self.z_dim = z_dim
        self.x_dim = x_dim
        self.nb_class = nb_class
        self.nb_epoch = nb_epoch
        self.batch_size = batch_size
        self.verbose = verbose
        self.print_frequency = print_frequency
        self.lr_d = lr_d
        self.lr_g = lr_g
        
        self.build_model()

    def generator(self, z, label, reuse=False):
        with tf.variable_scope("generator") as scope:
            if reuse:
                scope.reuse_variables()
            
            code = tf.one_hot(label,depth=self.nb_class)
            seed = tf.concat([z, code],axis=1)
                
            regularizer = tf.contrib.layers.l2_regularizer(scale=0.2)    

            h = tf.layers.dense(seed,20, activation=tf.nn.relu,kernel_regularizer=regularizer)
            h = tf.layers.dense(z,20, activation=tf.nn.relu,kernel_regularizer=regularizer)
            h = tf.layers.dense(h,self.x_dim)
            return h

    def discriminator(self, inp, reuse=False):
        with tf.variable_scope("discriminator") as scope:
            if reuse:
                scope.reuse_variables()
            regularizer = tf.contrib.layers.l2_regularizer(scale=0.2)    
            lasso = tf.contrib.layers.l2_regularizer(scale=0.8)    
            h = tf.layers.dense(inp,20, activation=tf.nn.relu,kernel_regularizer=regularizer)
            layer = h

            h = tf.layers.dense(h,20, activation=tf.nn.relu, kernel_regularizer=regularizer)
            with tf.variable_scope("classifier") as scope:
                class_logits = tf.layers.dense(h,self.nb_class,kernel_regularizer=lasso)
            dis = tf.layers.dense(h,1,kernel_regularizer=lasso)
            
            return class_logits, layer, dis

    def build_model(self):
        self.lab = tf.placeholder(tf.float32,[None,self.x_dim], name='input_lbl_data')
        self.unl = tf.placeholder(tf.float32,[None,self.x_dim], name='input_unl_data')
        self.z = tf.placeholder(tf.float32, [None,self.z_dim],name='z_seed')
        self.lbl = tf.placeholder(tf.int64, [None],name='labels')
        self.fake_lbl = tf.placeholder(tf.int64, [None],name='labels')
        
        self.gen = self.generator(self.z,self.fake_lbl,reuse=False)
        self.l_lab, self.layer_lab, self.dis_lab = self.discriminator(self.lab, reuse=False)
        self.l_unl, self.layer_r,self.dis_unl = self.discriminator(self.unl, reuse=True)
        self.l_fake, self.layer_f,self.dis_fake = self.discriminator(self.gen, reuse=True)
        
        xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits
        sigmoid = tf.nn.sigmoid_cross_entropy_with_logits
        self.d_loss = tf.reduce_mean(sigmoid(logits=self.dis_unl,labels=tf.ones_like(self.dis_unl)))+\
                        tf.reduce_mean(sigmoid(logits=self.dis_fake,labels=tf.zeros_like(self.dis_fake)))
        self.c_loss = tf.reduce_mean(xentropy(logits=self.l_lab,labels=self.lbl)) 
        m1=tf.reduce_mean(self.layer_r, axis=0)
        m2=tf.reduce_mean(self.layer_f, axis=0)
#         self.g_loss = tf.reduce_mean(tf.square(m1-m2))
        self.g_loss = tf.reduce_mean(sigmoid(logits=self.dis_fake,labels=tf.ones_like(self.dis_fake)))
        self.q_loss = 0.01 * tf.reduce_mean(xentropy(logits=self.l_fake,labels=self.fake_lbl))  

#         self.c_loss += self.q_loss
#         self.d_loss += self.q_loss
#         self.g_loss += self.q_loss
        #loss generator
        
        layer_split = tf.split(self.layer_lab, 10, axis=0)
        y = list(map(tf.reduce_mean, layer_split))
        
        self.cond_pen = tf.reduce_mean(tf.square(self.layer_r-self.layer_f),axis=0)
        
        self.prediction_fake = tf.cast(tf.argmax(self.l_lab,1),tf.int32)
        self.prediction = tf.cast(tf.argmax(self.l_lab,1),tf.int32)                                 

        self.correct_prediction = tf.equal(tf.argmax(self.l_lab, 1), self.lbl)
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
        self.dis = tf.cast(tf.greater(self.dis_lab[:,-1],0.0),tf.float32)
    
        t_vars = tf.trainable_variables()
        self.d_vars = [var for var in t_vars if 'discriminator' in var.name]
        self.g_vars = [var for var in t_vars if 'generator' in var.name] 
        self.c_vars = [var for var in t_vars if 'classifier' in var.name] 
        self.d_optim = tf.train.AdamOptimizer(self.lr_d).minimize(loss=self.d_loss, var_list=self.d_vars)
        self.g_optim = tf.train.AdamOptimizer(self.lr_g).minimize(loss=self.g_loss, var_list=self.g_vars)
        self.c_optim = tf.train.AdamOptimizer(self.lr_d).minimize(
            loss=self.c_loss, var_list=self.c_vars)
        print(self.d_vars)
        

    def train(self,f,ax, X_unl,X_lab, y, X_test,y_test):
        self.trainx_unl = X_unl
        self.trainx_unl2 = X_unl.copy()
        self.trainy = y
        self.trainx = X_lab
        self.testx = X_test
        self.testy = y_test
        
        self.nb_examples_unl = self.trainx_unl.shape[0]
        self.nb_examples_lab = self.trainx.shape[0]
        self.nb_step = self.nb_examples_unl//self.batch_size
        
        tx = []
        ty = []
        for t in range(self.nb_examples_unl//self.nb_examples_lab):
            inds = np.random.permutation(self.nb_examples_lab)
            tx.append(self.trainx[inds])
            ty.append(self.trainy[inds])
        self.trainx = np.concatenate(tx, axis=0)
        self.trainy = np.concatenate(ty, axis=0)

        self.sess.run(tf.global_variables_initializer())
        for epoch in range(self.nb_epoch):
            ll_d = 0

            for step in range(self.nb_step): 
                ids = np.random.permutation(self.trainx.shape[0])
                self.trainx = self.trainx[ids]
                self.trainy = self.trainy[ids]
                self.trainx_unl = self.trainx_unl[np.random.permutation(self.trainx_unl.shape[0])]
                self.trainx_unl2 = self.trainx_unl2[np.random.permutation(self.trainx_unl2.shape[0])]

                ll_d = 0
                ll_g = 0 
                ll_c = 0
                for step in range(self.nb_step):
                    ran_from = step * self.batch_size
                    ran_to = (step+1) * self.batch_size
                    
                    feed_dict={self.unl:self.trainx_unl[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.d_optim, self.d_loss],feed_dict=feed_dict)
                    ll_d += ll
                    
                    feed_dict={self.lab:self.trainx[ran_from:ran_to],
                               self.lbl:self.trainy[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.c_optim, self.c_loss],feed_dict=feed_dict)
                    ll_c += ll
                    
                    feed_dict={self.unl:self.trainx_unl2[ran_from:ran_to],
                               self.z:np.random.randn(self.batch_size,self.z_dim),
                               self.fake_lbl: np.random.randint(0,self.nb_class,self.batch_size)}
                    _, ll = self.sess.run([self.g_optim, self.g_loss],feed_dict=feed_dict)
                    ll_g += ll
                    
                ll_d /= self.nb_step
                ll_g /= self.nb_step 
                ll_c /= self.nb_step
                                           
            if (epoch % self.print_frequency == 0):
                train_acc = self.sess.run(self.accuracy,feed_dict={self.lab:X_lab,
                                                                   self.lbl:y})
                test_acc = self.sess.run(self.accuracy,feed_dict={self.lab:X_test, 
                                                                  self.lbl:y_test})

                print('epoch %d | loss d = %0.4f | loss g = %0.4f | loss c = %0.4f | train acc = %0.2f | test acc = %0.2f '
                      %(epoch, ll_d, ll_g,ll_c, train_acc*100, test_acc*100))
                plot_gan(f,ax)

    def predict(self, X_test, y_test=False,acc=False):
        if acc == False:  
            return self.sess.run(self.prediction ,feed_dict={self.lab:X_test})

        return self.sess.run([self.prediction, self.accuracy],feed_dict={self.lab:X_test,
                                                                         self.lbl:y_test})
        
    
    def predict_fake(self, X_test, y_test=False,acc=False):
        if acc == False:    
            return self.sess.run(self.prediction_fake ,feed_dict={self.lab:X_test})
        
        return self.sess.run([self.prediction, self.accuracy],feed_dict={self.lab:X_test,
                                                                         self.lbl:y_test})
                                         
    
    def discriminate(self, X_test, y_test=None):
        if y_test == None:     
            pred = self.sess.run(self.dis ,feed_dict={self.lab:X_test})
            return pred
                                 

    def generate_random_samples(self, nb_samples, label):
        return self.sess.run(self.gen,feed_dict={self.z:np.random.randn(nb_samples,self.z_dim),
                                                self.fake_lbl: label})

# %%
tf.reset_default_graph()
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
ssgan = Model(sess, nb_epoch=1000, lr_g=0.0003, lr_d=0.003, print_frequency=1,nb_class=4,batch_size=400)

f, ax = plt.subplots(1,3, sharex=True)
f.set_size_inches(10,3)
f.subplots_adjust(hspace=0.5)
plt.ion()
f.show()
f.canvas.draw()

ssgan.train(f,ax,X,X_lab,y_lab,X,y)
f.close()
# Out:
# [<tf.Variable 'discriminator/dense/kernel:0' shape=(2, 20) dtype=float32_ref>, <tf.Variable 'discriminator/dense/bias:0' shape=(20,) dtype=float32_ref>, <tf.Variable 'discriminator/dense_1/kernel:0' shape=(20, 20) dtype=float32_ref>, <tf.Variable 'discriminator/dense_1/bias:0' shape=(20,) dtype=float32_ref>, <tf.Variable 'discriminator/classifier/dense/kernel:0' shape=(20, 4) dtype=float32_ref>, <tf.Variable 'discriminator/classifier/dense/bias:0' shape=(4,) dtype=float32_ref>, <tf.Variable 'discriminator/dense_2/kernel:0' shape=(20, 1) dtype=float32_ref>, <tf.Variable 'discriminator/dense_2/bias:0' shape=(1,) dtype=float32_ref>]
# <img src="data:image/png;base64,..." width="999.4166358888987">
# epoch 0 | loss d = 1.3609 | loss g = 0.6942 | loss c = 1.4082 | train acc = 15.00 | test acc = 12.13
# epoch 1 | loss d = 1.3444 | loss g = 0.7115 | loss c = 1.4095 | train acc = 15.00 | test acc = 16.75
# epoch 2 | loss d = 1.3280 | loss g = 0.7293 | loss c = 1.4068 | train acc = 35.00 | test acc = 28.37
# epoch 3 | loss d = 1.3129 | loss g = 0.7441 | loss c = 1.4007 | train acc = 35.00 | test acc = 32.37
# epoch 4 | loss d = 1.2924 | loss g = 0.7612 | loss c = 1.3913 | train acc = 35.00 | test acc = 31.62
# epoch 5 | loss d = 1.2740 | loss g = 0.7748 | loss c = 1.3816 | train acc = 35.00 | test acc = 31.50
# epoch 6 | loss d = 1.2501 | loss g = 0.7927 | loss c = 1.3686 | train acc = 30.00 | test acc = 30.50
# epoch 7 | loss d = 1.2313 | loss g = 0.8015 | loss c = 1.3505 | train acc = 25.00 | test acc = 29.25
# epoch 8 | loss d = 1.2089 | loss g = 0.8173 | loss c = 1.3314 | train acc = 25.00 | test acc = 29.25
# epoch 9 | loss d = 1.1821 | loss g = 0.8336 | loss c = 1.3140 | train acc = 30.00 | test acc = 30.62
# epoch 10 | loss d = 1.1681 | loss g = 0.8564 | loss c = 1.2968 | train acc = 35.00 | test acc = 32.00
# epoch 11 | loss d = 1.1535 | loss g = 0.8786 | loss c = 1.2830 | train acc = 35.00 | test acc = 32.62
# epoch 12 | loss d = 1.1351 | loss g = 0.9063 | loss c = 1.2730 | train acc = 35.00 | test acc = 32.50
# epoch 13 | loss d = 1.1106 | loss g = 0.8995 | loss c = 1.2597 | train acc = 35.00 | test acc = 31.50
# epoch 14 | loss d = 1.1102 | loss g = 0.9287 | loss c = 1.2407 | train acc = 35.00 | test acc = 32.12
# epoch 15 | loss d = 1.1164 | loss g = 0.9127 | loss c = 1.2187 | train acc = 35.00 | test acc = 32.25
# epoch 16 | loss d = 1.1148 | loss g = 0.9644 | loss c = 1.1926 | train acc = 55.00 | test acc = 34.25
# epoch 17 | loss d = 1.1550 | loss g = 0.9690 | loss c = 1.1631 | train acc = 60.00 | test acc = 37.37
# epoch 18 | loss d = 1.1368 | loss g = 1.0024 | loss c = 1.1364 | train acc = 75.00 | test acc = 43.63
# epoch 19 | loss d = 1.1914 | loss g = 0.9626 | loss c = 1.1091 | train acc = 80.00 | test acc = 52.00
# epoch 20 | loss d = 1.2391 | loss g = 0.9683 | loss c = 1.0848 | train acc = 80.00 | test acc = 62.88
# epoch 21 | loss d = 1.2340 | loss g = 0.9769 | loss c = 1.0600 | train acc = 90.00 | test acc = 67.25
# epoch 22 | loss d = 1.2307 | loss g = 0.9430 | loss c = 1.0352 | train acc = 90.00 | test acc = 70.37
# epoch 23 | loss d = 1.2851 | loss g = 0.9356 | loss c = 1.0137 | train acc = 90.00 | test acc = 71.62
# epoch 24 | loss d = 1.2921 | loss g = 0.9256 | loss c = 0.9971 | train acc = 95.00 | test acc = 71.75
# epoch 25 | loss d = 1.2908 | loss g = 0.8715 | loss c = 0.9779 | train acc = 95.00 | test acc = 72.25
# epoch 26 | loss d = 1.3055 | loss g = 0.8719 | loss c = 0.9652 | train acc = 95.00 | test acc = 73.63
# epoch 27 | loss d = 1.3433 | loss g = 0.8517 | loss c = 0.9558 | train acc = 100.00 | test acc = 74.12
# epoch 80 | loss d = 1.2392 | loss g = 0.8799 | loss c = 0.3812 | train acc = 95.00 | test acc = 73.37
# epoch 81 | loss d = 1.2426 | loss g = 0.8845 | loss c = 0.3729 | train acc = 95.00 | test acc = 73.12
# epoch 82 | loss d = 1.2195 | loss g = 0.8934 | loss c = 0.3629 | train acc = 95.00 | test acc = 72.87
# epoch 83 | loss d = 1.2284 | loss g = 0.9039 | loss c = 0.3594 | train acc = 100.00 | test acc = 73.75
# epoch 84 | loss d = 1.2227 | loss g = 0.8914 | loss c = 0.3622 | train acc = 100.00 | test acc = 74.37
# epoch 85 | loss d = 1.2386 | loss g = 0.8791 | loss c = 0.3572 | train acc = 100.00 | test acc = 74.75
# epoch 86 | loss d = 1.2325 | loss g = 0.9169 | loss c = 0.3444 | train acc = 100.00 | test acc = 74.87
# epoch 87 | loss d = 1.2367 | loss g = 0.8773 | loss c = 0.3370 | train acc = 100.00 | test acc = 74.00
# epoch 88 | loss d = 1.2088 | loss g = 0.9174 | loss c = 0.3318 | train acc = 100.00 | test acc = 73.62
# epoch 89 | loss d = 1.2242 | loss g = 0.8643 | loss c = 0.3258 | train acc = 95.00 | test acc = 73.62
# epoch 90 | loss d = 1.2326 | loss g = 0.9179 | loss c = 0.3197 | train acc = 95.00 | test acc = 74.00
# epoch 91 | loss d = 1.2333 | loss g = 0.9280 | loss c = 0.3099 | train acc = 100.00 | test acc = 74.75
# epoch 92 | loss d = 1.2261 | loss g = 0.9185 | loss c = 0.3000 | train acc = 100.00 | test acc = 74.50
# epoch 93 | loss d = 1.2191 | loss g = 0.8922 | loss c = 0.2990 | train acc = 100.00 | test acc = 74.75
# epoch 94 | loss d = 1.2360 | loss g = 0.9139 | loss c = 0.2965 | train acc = 100.00 | test acc = 76.12
# epoch 95 | loss d = 1.2113 | loss g = 0.8820 | loss c = 0.2928 | train acc = 100.00 | test acc = 76.13
# epoch 96 | loss d = 1.2251 | loss g = 0.9102 | loss c = 0.2881 | train acc = 100.00 | test acc = 75.37
# epoch 97 | loss d = 1.2287 | loss g = 0.9344 | loss c = 0.2916 | train acc = 100.00 | test acc = 75.00
# epoch 98 | loss d = 1.2248 | loss g = 0.9205 | loss c = 0.2849 | train acc = 100.00 | test acc = 74.62
# epoch 99 | loss d = 1.2358 | loss g = 0.9346 | loss c = 0.2789 | train acc = 100.00 | test acc = 75.00
# epoch 100 | loss d = 1.2200 | loss g = 0.9116 | loss c = 0.2793 | train acc = 100.00 | test acc = 74.75
# epoch 101 | loss d = 1.2202 | loss g = 0.9328 | loss c = 0.2725 | train acc = 100.00 | test acc = 75.50
# epoch 102 | loss d = 1.2234 | loss g = 0.9306 | loss c = 0.2689 | train acc = 100.00 | test acc = 76.12
# epoch 103 | loss d = 1.2332 | loss g = 0.9304 | loss c = 0.2684 | train acc = 100.00 | test acc = 75.62
# epoch 104 | loss d = 1.2325 | loss g = 0.8951 | loss c = 0.2637 | train acc = 100.00 | test acc = 75.87
# epoch 234 | loss d = 1.1148 | loss g = 1.0779 | loss c = 0.0426 | train acc = 100.00 | test acc = 78.25
# epoch 235 | loss d = 1.1185 | loss g = 1.0368 | loss c = 0.0406 | train acc = 100.00 | test acc = 78.87
# epoch 236 | loss d = 1.1285 | loss g = 1.1018 | loss c = 0.0406 | train acc = 100.00 | test acc = 78.87
# epoch 237 | loss d = 1.0953 | loss g = 1.0249 | loss c = 0.0410 | train acc = 100.00 | test acc = 78.25
# epoch 238 | loss d = 1.1114 | loss g = 1.0652 | loss c = 0.0406 | train acc = 100.00 | test acc = 78.25
# epoch 239 | loss d = 1.1203 | loss g = 1.0559 | loss c = 0.0394 | train acc = 100.00 | test acc = 78.75
# epoch 240 | loss d = 1.1035 | loss g = 1.0586 | loss c = 0.0388 | train acc = 100.00 | test acc = 78.25
# epoch 241 | loss d = 1.1039 | loss g = 1.0620 | loss c = 0.0394 | train acc = 100.00 | test acc = 78.12
# epoch 242 | loss d = 1.1035 | loss g = 1.1084 | loss c = 0.0400 | train acc = 100.00 | test acc = 78.00
# epoch 243 | loss d = 1.1108 | loss g = 1.0570 | loss c = 0.0389 | train acc = 100.00 | test acc = 78.12
# epoch 244 | loss d = 1.1166 | loss g = 1.1134 | loss c = 0.0386 | train acc = 100.00 | test acc = 77.88
# epoch 245 | loss d = 1.0992 | loss g = 1.0334 | loss c = 0.0370 | train acc = 100.00 | test acc = 78.50
# epoch 246 | loss d = 1.1187 | loss g = 1.0785 | loss c = 0.0355 | train acc = 100.00 | test acc = 78.00
# epoch 247 | loss d = 1.0994 | loss g = 1.1436 | loss c = 0.0353 | train acc = 100.00 | test acc = 78.37
# epoch 248 | loss d = 1.1153 | loss g = 1.0998 | loss c = 0.0347 | train acc = 100.00 | test acc = 78.37
# epoch 249 | loss d = 1.1058 | loss g = 1.1092 | loss c = 0.0329 | train acc = 100.00 | test acc = 78.25
# epoch 250 | loss d = 1.1023 | loss g = 1.1075 | loss c = 0.0339 | train acc = 100.00 | test acc = 78.00
# epoch 251 | loss d = 1.1107 | loss g = 1.1134 | loss c = 0.0339 | train acc = 100.00 | test acc = 77.87
# epoch 252 | loss d = 1.1210 | loss g = 1.1700 | loss c = 0.0324 | train acc = 100.00 | test acc = 78.00
# epoch 253 | loss d = 1.1048 | loss g = 1.0859 | loss c = 0.0323 | train acc = 100.00 | test acc = 78.37
# epoch 254 | loss d = 1.1240 | loss g = 1.1585 | loss c = 0.0318 | train acc = 100.00 | test acc = 78.25
# epoch 255 | loss d = 1.0929 | loss g = 1.0772 | loss c = 0.0315 | train acc = 100.00 | test acc = 77.88
# epoch 256 | loss d = 1.0908 | loss g = 1.0797 | loss c = 0.0310 | train acc = 100.00 | test acc = 77.75
# epoch 257 | loss d = 1.0682 | loss g = 1.1282 | loss c = 0.0295 | train acc = 100.00 | test acc = 78.00
# epoch 258 | loss d = 1.0886 | loss g = 1.1681 | loss c = 0.0288 | train acc = 100.00 | test acc = 78.00
# epoch 259 | loss d = 1.1065 | loss g = 1.0347 | loss c = 0.0286 | train acc = 100.00 | test acc = 78.00
# epoch 260 | loss d = 1.0988 | loss g = 1.0933 | loss c = 0.0283 | train acc = 100.00 | test acc = 78.62
# epoch 261 | loss d = 1.0846 | loss g = 1.2070 | loss c = 0.0274 | train acc = 100.00 | test acc = 77.63
# epoch 262 | loss d = 1.0650 | loss g = 1.0016 | loss c = 0.0277 | train acc = 100.00 | test acc = 77.50
# epoch 263 | loss d = 1.0767 | loss g = 1.1309 | loss c = 0.0284 | train acc = 100.00 | test acc = 77.75
# epoch 264 | loss d = 1.0810 | loss g = 1.1566 | loss c = 0.0276 | train acc = 100.00 | test acc = 78.37
# epoch 265 | loss d = 1.0692 | loss g = 1.0879 | loss c = 0.0261 | train acc = 100.00 | test acc = 78.88
# epoch 266 | loss d = 1.1017 | loss g = 1.1388 | loss c = 0.0248 | train acc = 100.00 | test acc = 78.50
# epoch 267 | loss d = 1.0855 | loss g = 1.0807 | loss c = 0.0253 | train acc = 100.00 | test acc = 78.12
# epoch 268 | loss d = 1.1069 | loss g = 1.1508 | loss c = 0.0255 | train acc = 100.00 | test acc = 77.87
# epoch 269 | loss d = 1.0839 | loss g = 1.1408 | loss c = 0.0260 | train acc = 100.00 | test acc = 77.75
# epoch 270 | loss d = 1.0710 | loss g = 1.0819 | loss c = 0.0273 | train acc = 100.00 | test acc = 77.50
# epoch 271 | loss d = 1.0910 | loss g = 1.1766 | loss c = 0.0256 | train acc = 100.00 | test acc = 76.50
# epoch 272 | loss d = 1.0793 | loss g = 1.0836 | loss c = 0.0248 | train acc = 100.00 | test acc = 77.00
# epoch 273 | loss d = 1.0676 | loss g = 1.1471 | loss c = 0.0251 | train acc = 100.00 | test acc = 77.50
# epoch 274 | loss d = 1.0841 | loss g = 1.1852 | loss c = 0.0242 | train acc = 100.00 | test acc = 77.50
# epoch 275 | loss d = 1.0767 | loss g = 1.1095 | loss c = 0.0235 | train acc = 100.00 | test acc = 77.50
# epoch 276 | loss d = 1.0736 | loss g = 1.1663 | loss c = 0.0234 | train acc = 100.00 | test acc = 77.63
# epoch 277 | loss d = 1.0919 | loss g = 1.0956 | loss c = 0.0225 | train acc = 100.00 | test acc = 77.50
# epoch 278 | loss d = 1.0728 | loss g = 1.2007 | loss c = 0.0223 | train acc = 100.00 | test acc = 77.87
# epoch 279 | loss d = 1.0675 | loss g = 1.2072 | loss c = 0.0217 | train acc = 100.00 | test acc = 78.12
# epoch 280 | loss d = 1.0759 | loss g = 1.0820 | loss c = 0.0219 | train acc = 100.00 | test acc = 78.00
# epoch 281 | loss d = 1.0581 | loss g = 1.2014 | loss c = 0.0216 | train acc = 100.00 | test acc = 78.25
# epoch 282 | loss d = 1.0706 | loss g = 1.0966 | loss c = 0.0212 | train acc = 100.00 | test acc = 78.12
# epoch 283 | loss d = 1.0598 | loss g = 1.2188 | loss c = 0.0208 | train acc = 100.00 | test acc = 77.13
# epoch 284 | loss d = 1.0758 | loss g = 1.1213 | loss c = 0.0204 | train acc = 100.00 | test acc = 77.50
# epoch 285 | loss d = 1.0748 | loss g = 1.1665 | loss c = 0.0201 | train acc = 100.00 | test acc = 77.75
# epoch 286 | loss d = 1.0743 | loss g = 1.1599 | loss c = 0.0201 | train acc = 100.00 | test acc = 78.00
# epoch 287 | loss d = 1.0913 | loss g = 1.2482 | loss c = 0.0201 | train acc = 100.00 | test acc = 78.00
# epoch 288 | loss d = 1.0737 | loss g = 1.1720 | loss c = 0.0197 | train acc = 100.00 | test acc = 78.25
# epoch 289 | loss d = 1.0481 | loss g = 1.1867 | loss c = 0.0193 | train acc = 100.00 | test acc = 77.88
# epoch 290 | loss d = 1.0514 | loss g = 1.1509 | loss c = 0.0184 | train acc = 100.00 | test acc = 78.12
# epoch 291 | loss d = 1.0539 | loss g = 1.2455 | loss c = 0.0179 | train acc = 100.00 | test acc = 78.25
# epoch 292 | loss d = 1.0626 | loss g = 1.1502 | loss c = 0.0179 | train acc = 100.00 | test acc = 77.87
# epoch 293 | loss d = 1.0705 | loss g = 1.2264 | loss c = 0.0174 | train acc = 100.00 | test acc = 77.88
# epoch 294 | loss d = 1.0608 | loss g = 1.1451 | loss c = 0.0170 | train acc = 100.00 | test acc = 77.50
# epoch 295 | loss d = 1.0503 | loss g = 1.1793 | loss c = 0.0171 | train acc = 100.00 | test acc = 77.38
# epoch 296 | loss d = 1.0662 | loss g = 1.1579 | loss c = 0.0169 | train acc = 100.00 | test acc = 77.37
# epoch 297 | loss d = 1.0551 | loss g = 1.1584 | loss c = 0.0173 | train acc = 100.00 | test acc = 77.50
# epoch 298 | loss d = 1.0450 | loss g = 1.1727 | loss c = 0.0174 | train acc = 100.00 | test acc = 77.13
# epoch 299 | loss d = 1.0556 | loss g = 1.1967 | loss c = 0.0165 | train acc = 100.00 | test acc = 77.13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-d79d1602a0d8> in <module>()
#      10 f.canvas.draw()
#      11
# ---> 12 ssgan.train(f,ax,X,X_lab,y_lab,X,y)
#      13 f.close()
#
# <ipython-input-61-c52ea49729a6> in train(self, f, ax, X_unl, X_lab, y, X_test, y_test)
#     166                 print('epoch %d | loss d = %0.4f | loss g = %0.4f | loss c = %0.4f | train acc = %0.2f | test acc = %0.2f '
#     167                       %(epoch, ll_d, ll_g,ll_c, train_acc*100, test_acc*100))
# --> 168                 plot_gan(f,ax)
#     169
#     170     def predict(self, X_test, y_test=False,acc=False):
#
# <ipython-input-18-7940521705ee> in plot_gan(f, ax)
#      36     ax[2].set_ylim(ymin,ymax)
#      37
# ---> 38     f.canvas.draw()
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     176         backend_agg.RendererAgg.lock.acquire()
#     177         try:
# --> 178             self.figure.draw(renderer)
#     179         finally:
#     180             backend_agg.RendererAgg.lock.release()
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/collections.py in draw(self, renderer)
#     872     def draw(self, renderer):
#     873         self.set_sizes(self._sizes, self.figure.dpi)
# --> 874         Collection.draw(self, renderer)
#     875
#     876
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/collections.py in draw(self, renderer)
#     284         renderer.open_group(self.__class__.__name__, self.get_gid())
#     285
# --> 286         self.update_scalarmappable()
#     287
#     288         transform, transOffset, offsets, paths = self._prepare_points()
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/collections.py in update_scalarmappable(self)
#     762         from scalar data
#     763         """
# --> 764         if self._A is None:
#     765             return
#     766         if self._A.ndim > 1:
#
# KeyboardInterrupt:

# %%
X.shape
# Out:
# (800, 2)
